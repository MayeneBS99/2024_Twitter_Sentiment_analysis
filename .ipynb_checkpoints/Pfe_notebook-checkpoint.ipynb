# %%
#loading libraries
# !pip install pyodbc
# Out:
# Requirement already satisfied: pyodbc in c:\users\mayen\anaconda3\lib\site-packages (5.2.0)
# [notice] A new release of pip is available: 23.3.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install git+https://github.com/huggingface/transformers -q
# Out:
# [notice] A new release of pip is available: 23.3.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# libraries loading

import pandas as pd
import numpy as np
import pyodbc

import tensorflow
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

#NLP prepeocess
import nltk
import re

import openai

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 0. Pre-processing

# %%
# datasets loading

france_0102_df = pd.read_csv("tweets_fr_0102.csv")
france_0305_df = pd.read_csv("tweets_fr_0305.csv")
france_0609_df = pd.read_csv("tweets_france_juin_sep.csv")

england_0102_df = pd.read_csv("tweets_england_0102.csv")
england_0305_df = pd.read_csv("tweets_england_0305.csv")
england_0609_df = pd.read_csv("tweets_england_juin_sep.csv")

usa_0102_df = pd.read_csv("tweets_usa0102.csv")
usa_0305_df = pd.read_csv("tweets_usa_mars_mai.csv")
usa_0609_df = pd.read_csv("tweets_usa_juin_sep.csv")

# %%
print("france_0102_df\n", france_0102_df.shape)
print("france_0305_df\n", france_0305_df.shape)
print("france_0609_df\n", france_0609_df.shape)

print("england_0102_df\n", england_0102_df.shape)
print("england_0305_df\n", england_0305_df.shape)
print("england_0609_df\n", england_0609_df.shape)

print("usa_0102_df\n", usa_0102_df.shape)
print("usa_0305_df\n", usa_0305_df.shape)
print("usa_0609_df\n", usa_0609_df.shape)
# Out:
# france_0102_df
#  (255, 6)
# france_0305_df
#  (224, 6)
# france_0609_df
#  (1013, 6)
# england_0102_df
#  (260, 6)
# england_0305_df
#  (199, 6)
# england_0609_df
#  (357, 6)
# usa_0102_df
#  (207, 6)
# usa_0305_df
#  (219, 6)
# usa_0609_df
#  (199, 6)

# %%
# add a new column for all our datasets for specify country 


france_0102_df["country"] = "France"
france_0305_df["country"] = "France"
france_0609_df["country"] = "France"

england_0102_df["country"] = "England"
england_0305_df["country"] = "England"
england_0609_df["country"] = "England"

usa_0102_df["country"] = "Usa"
usa_0305_df["country"] = "Usa"
usa_0609_df["country"] = "Usa"


# remove the tweet_count column
france_0102_df = france_0102_df.drop(columns = ["Tweet_count"], axis = 1)
france_0305_df = france_0305_df.drop(columns = ["Tweet_count"], axis = 1)
france_0609_df = france_0609_df.drop(columns = ["Tweet_count"], axis = 1)

england_0102_df = england_0102_df.drop(columns = ["Tweet_count"], axis = 1)
england_0305_df = england_0305_df.drop(columns = ["Tweet_count"], axis = 1)
england_0609_df = england_0609_df.drop(columns = ["Tweet_count"], axis = 1)

usa_0102_df = usa_0102_df.drop(columns = ["Tweet_count"], axis = 1)
usa_0305_df = usa_0305_df.drop(columns = ["Tweet_count"], axis = 1)
usa_0609_df = usa_0609_df.drop(columns = ["Tweet_count"], axis = 1)

# %%
france_0305_df
# Out:
#      Tweet_count                          Username  \
# 0              1                         𝗙𝗿𝗮𝗻𝗰𝗲 🇫🇷
# 1              2  Jean Condamine 🇫🇷 🇪🇸 🇬🇧 🇫🇷 🇫🇷 🇫🇷
# 2              3                 Pierre-Marie Sève
# 3              4                      FranceRMCF🇫🇷
# 4              5                    Netflix France
# ..           ...                               ...
# 219          220                          L'ÉQUIPE
# 220          221                France Télévisions
# 221          222                        franceinfo
# 222          223                        franceinfo
# 223          224                             RAŽ⛩️
#
#                                                   Text  \
# 0    Voilà le vainqueur de #Eurovision2024  ou l'éc...
# 1    Le FMI abaisse la prévision de croissance du P...
# 2    Il est controversé mais attendu, le classement...
# 3    🚨LE REAL MADRID AFFRONTE LE DORTMUND CE SAMEDI...
# 4    "2024 c’est mon année"                mars htt...
# ..                                                 ...
# 219  Pour Philipp Lahm, ancien international allema...
# 220  🇫🇷🎤#Eurovision2024 | Félicitations à @Slimaneo...
# 221  Paris 2024 : la nageuse Laure Manaudou sera la...
# 222  Cérémonie d'ouverture de Paris 2024 : "On veut...
# 223  France’s 2024 Euro squad is a joke. \n\nExpect...
#
#                          Created At  Retweets  Likes
# 0    Sun May 12 07:48:36 +0000 2024       658   2704
# 1    Wed Apr 24 06:52:42 +0000 2024       148    215
# 2    Wed May 22 12:40:44 +0000 2024      5694   9442
# 3    Thu May 30 20:14:49 +0000 2024         2     87
# 4    Thu Mar 14 10:14:06 +0000 2024       621   4814
# ..                              ...       ...    ...
# 219  Tue Mar 26 13:01:01 +0000 2024        30    314
# 220  Sat May 11 22:53:04 +0000 2024       256   1482
# 221  Mon Apr 15 13:08:01 +0000 2024        30    232
# 222  Wed Mar 06 11:30:27 +0000 2024       163    203
# 223  Thu May 16 20:39:38 +0000 2024        24    468
#
# [224 rows x 6 columns]

# %%
# transforming and renamming the Created At column for all the datasets

def modify_value(vector):
    month_actual = vector.split(' ')[1]
    month_match = {"Jan" : "January",
                    "Feb" : "February",
                    "Mar" : "March",
                    "Apr" : "April",
                    "May" : "May",
                    "Jun" : "June",
                    "Jul" : "July",
                    "Aug" : "August",
                    "Sep" : "September"
                   }
    
    return month_match.get(month_actual, month_match)

# application 
france_0102_df["Created At"] = france_0102_df["Created At"].apply(modify_value)
france_0305_df["Created At"] = france_0305_df["Created At"].apply(modify_value)
france_0609_df["Created At"] = france_0609_df["Created At"].apply(modify_value)

england_0102_df["Created At"] = england_0102_df["Created At"].apply(modify_value)
england_0305_df["Created At"] = england_0305_df["Created At"].apply(modify_value)
england_0609_df["Created At"] = england_0609_df["Created At"].apply(modify_value)

usa_0102_df["Created At"] = usa_0102_df["Created At"].apply(modify_value)
usa_0305_df["Created At"] = usa_0305_df["Created At"].apply(modify_value)
usa_0609_df["Created At"] = usa_0609_df["Created At"].apply(modify_value)

# %%
france_0102_df = france_0102_df.rename(columns = {"Created At": "Month"})
france_0305_df = france_0305_df.rename(columns = {"Created At": "Month"})
france_0609_df = france_0609_df.rename(columns = {"Created At": "Month"})

england_0102_df = england_0102_df.rename(columns = {"Created At": "Month"})
england_0305_df = england_0305_df.rename(columns = {"Created At": "Month"})
england_0609_df = england_0609_df.rename(columns = {"Created At": "Month"})

usa_0102_df = usa_0102_df.rename(columns = {"Created At": "Month"})
usa_0305_df = usa_0305_df.rename(columns = {"Created At": "Month"})
usa_0609_df = usa_0609_df.rename(columns = {"Created At": "Month"})

# %%
# affichage des datasets:

france_0102_df
# Out:
#             Username                                               Text  \
# 0     Keur Soxna Mai  Chère communauté,                             ...
# 1          Actu Foot  🚨 𝗟𝗔 𝗙𝗥𝗔𝗡𝗖𝗘 𝗘𝗦𝗧 𝗦𝗔𝗖𝗥𝗘́𝗘 𝗖𝗛𝗔𝗠𝗣𝗜𝗢𝗡𝗡𝗘 𝗗'𝗘𝗨𝗥𝗢𝗣𝗘 𝗗𝗘...
# 2              momow  @letheoricien228 Les prix montent, les salaire...
# 3     Netflix France  Le Cercle des neiges (2024), par J.A. Bayona h...
# 4     QuotidienSport  🇫🇷 LA FRANCE EST CHAMPIONNE D’EUROPE 2024 !!!!...
# ..               ...                                                ...
# 250   Conf' Paysanne  Et en France !?  Seule la @ConfPaysanne se mob...
# 251  Corentin Sellin  Le replay de l'émission @Cdanslair  de ce merc...
# 252     France Inter  #LInconscient vous répond ! Posez vos question...
# 253  Maryline Cabane  Félicitations à notre Partenaire @FFF @Orange_...
# 254    Basket Europe  🏀 Ce qu’il faut retenir des salaires de la sai...
#
#         Month  Retweets  Likes country
# 0    February        29     63  France
# 1     January      2514  27681  France
# 2     January        11    290  France
# 3     January       115   1159  France
# 4     January        74    579  France
# ..        ...       ...    ...     ...
# 250  February       365    751  France
# 251  February         4     26  France
# 252  February         1      3  France
# 253  February         2     20  France
# 254  February         0      2  France
#
# [255 rows x 6 columns]

# %%
def remove_characters(characters):
    # Remove hyperlinks
    characters = re.sub(r'https?://[^\s\n\r]+', '', characters)

    # Remove special characters (seulement le #, mais on garde les mots associés)
    characters = re.sub(r'#', '', characters)  # Retirer juste le #

    # Replace non-breaking spaces et nouvelles lignes
    characters = characters.replace('\xa0', ' ').replace('\n', ' ')

    # Remove punctuation, conserver lettres et espaces seulement
    characters = re.sub(r"[^\w\s]", "", characters)
    
#     # Optional: Retirer les chiffres
#     characters = re.sub(r'\d+', '', characters)
    
#     # Supprimer les espaces en trop
#     characters = " ".join(characters.split())

    return characters

# %%
# application de la fonction

 
france_0102_df["Text_clean1"] = france_0102_df["Text"].apply(remove_characters)
france_0305_df["Text_clean1"] = france_0305_df["Text"].apply(remove_characters)
france_0609_df["Text_clean1"] = france_0609_df["Text"].apply(remove_characters)

england_0102_df["Text_clean1"] = england_0102_df["Text"].apply(remove_characters)
england_0305_df["Text_clean1"] = england_0305_df["Text"].apply(remove_characters)
england_0609_df["Text_clean1"] = england_0609_df["Text"].apply(remove_characters)

usa_0102_df["Text_clean1"] = usa_0102_df["Text"].apply(remove_characters)
usa_0305_df["Text_clean1"] = usa_0305_df["Text"].apply(remove_characters)
usa_0609_df["Text_clean1"] = usa_0609_df["Text"].apply(remove_characters)

# %%
# test
print(usa_0609_df["Text"][50])
print(usa_0609_df["Text_clean1"][50])
# Out:
# So far this summer...
#
# -A shame Trump trial &amp; conviction.
# -Presidential immunity upheld.
# -The Trump documents case is dropped.
# -The debate.
# -An attempted assassination.
# -JD Vance is Trumps VP.
# -Joe Biden "drops out."
# -Kamala is the presumptive nominee.
#
# None of this is normal.
# So far this summer  A shame Trump trial amp conviction Presidential immunity upheld The Trump documents case is dropped The debate An attempted assassination JD Vance is Trumps VP Joe Biden drops out Kamala is the presumptive nominee  None of this is normal

# %% [markdown]
# # 1. Data Translation
#
# ## With HuggingFace API
#
# In this part we gonna try to translate our french tweetws in english to have the same language for all our tweets

# %%
# create a function

def translate(texte):
    model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
    tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")

    tokenizer.src_lang = "fr_XX"
    encoded_fr = tokenizer(texte, return_tensors = "pt")

    generated_tokens = model.generate(
        **encoded_fr,
        forced_bos_token_id=tokenizer.lang_code_to_id["en_XX"]
    )
    texte = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)
    
    return texte

# %%
# test
print(france_0102_df["Text_clean1"][252])
# Out:
# LInconscient vous répond  Posez vos questions au psychanalyste JeanPierre Winter en suivant ce lien

# %%
translate(france_0102_df["Text_clean1"][252])
# Out:
# ['LInconscient you answer Ask the psychanalyst JeanPierre Winter by following this link']

# %%
france_0102_df["Text_clean1"] = france_0102_df["Text_clean1"].apply(translate)
france_0305_df["Text_clean1"] = france_0305_df["Text_clean1"].apply(translate)
france_0609_df["Text_clean1"] = france_0609_df["Text_clean1"].apply(translate)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 2
#       1 france_0102_df["Text_clean1"] = france_0102_df["Text_clean1"].apply(translate)
# ----> 2 france_0305_df["Text_clean1"] = france_0305_df["Text_clean1"].apply(translate)
#       3 france_0609_df["Text_clean1"] = france_0609_df["Text_clean1"].apply(translate)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:4904, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4769 def apply(
#    4770     self,
#    4771     func: AggFuncType,
#    (...)
#    4776     **kwargs,
#    4777 ) -> DataFrame | Series:
#    4778     """
#    4779     Invoke function on values of Series.
#    4780
#    (...)
#    4895     dtype: float64
#    4896     """
#    4897     return SeriesApply(
#    4898         self,
#    4899         func,
#    4900         convert_dtype=convert_dtype,
#    4901         by_row=by_row,
#    4902         args=args,
#    4903         kwargs=kwargs,
# -> 4904     ).apply()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[44], line 4, in translate(texte)
#       3 def translate(texte):
# ----> 4     model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
#       5     tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
#       7     tokenizer.src_lang = "fr_XX"
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_utils.py:4238, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4228     if dtype_orig is not None:
#    4229         torch.set_default_dtype(dtype_orig)
#    4231     (
#    4232         model,
#    4233         missing_keys,
#    4234         unexpected_keys,
#    4235         mismatched_keys,
#    4236         offload_index,
#    4237         error_msgs,
# -> 4238     ) = cls._load_pretrained_model(
#    4239         model,
#    4240         state_dict,
#    4241         loaded_state_dict_keys,  # XXX: rename?
#    4242         resolved_archive_file,
#    4243         pretrained_model_name_or_path,
#    4244         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    4245         sharded_metadata=sharded_metadata,
#    4246         _fast_init=_fast_init,
#    4247         low_cpu_mem_usage=low_cpu_mem_usage,
#    4248         device_map=device_map,
#    4249         offload_folder=offload_folder,
#    4250         offload_state_dict=offload_state_dict,
#    4251         dtype=torch_dtype,
#    4252         hf_quantizer=hf_quantizer,
#    4253         keep_in_fp32_modules=keep_in_fp32_modules,
#    4254         gguf_path=gguf_path,
#    4255         weights_only=weights_only,
#    4256     )
#    4258 # make sure token embedding weights are still tied if needed
#    4259 model.tie_weights()
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_utils.py:4553, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_modules, gguf_path, weights_only)
#    4551             model.apply(model._initialize_weights)
#    4552     else:
# -> 4553         model.apply(model._initialize_weights)
#    4555 # Set some modules to fp32 if any
#    4556 if keep_in_fp32_modules is not None:
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1029, in Module.apply(self, fn)
#     993 r"""Apply ``fn`` recursively to every submodule (as returned by ``.children()``) as well as self.
#     994
#     995 Typical use includes initializing the parameters of a model
#    (...)
#    1026
#    1027 """
#    1028 for module in self.children():
# -> 1029     module.apply(fn)
#    1030 fn(self)
#    1031 return self
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1029, in Module.apply(self, fn)
#     993 r"""Apply ``fn`` recursively to every submodule (as returned by ``.children()``) as well as self.
#     994
#     995 Typical use includes initializing the parameters of a model
#    (...)
#    1026
#    1027 """
#    1028 for module in self.children():
# -> 1029     module.apply(fn)
#    1030 fn(self)
#    1031 return self
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1029, in Module.apply(self, fn)
#     993 r"""Apply ``fn`` recursively to every submodule (as returned by ``.children()``) as well as self.
#     994
#     995 Typical use includes initializing the parameters of a model
#    (...)
#    1026
#    1027 """
#    1028 for module in self.children():
# -> 1029     module.apply(fn)
#    1030 fn(self)
#    1031 return self
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1030, in Module.apply(self, fn)
#    1028 for module in self.children():
#    1029     module.apply(fn)
# -> 1030 fn(self)
#    1031 return self
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_utils.py:1922, in PreTrainedModel._initialize_weights(self, module)
#    1920 if getattr(module, "_is_hf_initialized", False):
#    1921     return
# -> 1922 self._init_weights(module)
#    1923 module._is_hf_initialized = True
#
# File ~\anaconda3\Lib\site-packages\transformers\models\mbart\modeling_mbart.py:758, in MBartPreTrainedModel._init_weights(self, module)
#     756         module.bias.data.zero_()
#     757 elif isinstance(module, nn.Embedding):
# --> 758     module.weight.data.normal_(mean=0.0, std=std)
#     759     if module.padding_idx is not None:
#     760         module.weight.data[module.padding_idx].zero_()
#
# KeyboardInterrupt:

# %% [markdown]
# ## With OpenAI API

# %%
openai.api_key = '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'

def traduire_tweet(tweet):
    response = openai.chat.completions.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role": "system", "content" : "Tu es un traducteur du français vers l'anglais" },
        {"role": "user", "content": f"Traduisez ce tweet en anglais : {tweet}"}
           
    ])
    return response.choices[0].message.content

# %%
# test
print(france_0102_df["Text_clean1"][252])
print("traduction : \n", traduire_tweet(france_0102_df["Text_clean1"][252]))
# Out:
# LInconscient vous répond  Posez vos questions au psychanalyste JeanPierre Winter en suivant ce lien
# traduction :
#  The unconscious responds to you. Ask your questions to psychoanalyst Jean-Pierre Winter by following this link.

# %%
# execution sur tous nos tweets
france_0102_df["Text_clean1"] = france_0102_df["Text_clean1"].apply(traduire_tweet)
france_0305_df["Text_clean1"] = france_0305_df["Text_clean1"].apply(traduire_tweet)
france_0609_df["Text_clean1"] = france_0609_df["Text_clean1"].apply(traduire_tweet)

# %%
print(france_0609_df["Text"][2])
print(france_0609_df["Text_clean1"][2])
# Out:
# Quand la Ve République a été créée, les femmes devaient demander l'autorisation à leur mari pour travailler. La contraception était interdite et le viol n'était pas reconnu comme un crime.
#
# Les générations de femmes qui ont gagné ces droits sont la nouvelle France. https://t.co/d5xqYPIXb3
# When the Fifth Republic was created, women had to ask their husbands for permission to work. Contraception was forbidden, and rape was not recognized as a crime. The generations of women who have won these rights are the new France.

# %%
france_0609_df
# Out:
#                      Username  \
# 0                WORLD 2024 🌊
# 1               Appart Design
# 2          Jean-Luc Mélenchon
# 3                 Marc Warnod
# 4                POMPOM POMME
# ...                       ...
# 1008  Renaissance Puy-de-Dôme
# 1009                Raphaël ⏚
# 1010          The-best-man-57
# 1011                  Polnews
# 1012   SYNÉPHILE / SYN.TATTOO
#
#                                                    Text      Month  Retweets  \
# 0                 Paris, France https://t.co/5j6PXTJ7m5  September       356
# 1           Côte d'Azur, France https://t.co/TtIZF0xjzw  September       900
# 2     Quand la Ve République a été créée, les femmes...  September       484
# 3     Une racaille inconnue, proche de députés LFI, ...  September      2606
# 4     Un charme vraiment unique ! 🔥😎\n\nCR 依枕云屏 - Pi...  September       918
# ...                                                 ...        ...       ...
# 1008  Une quinzaine olympique merveilleuse vient de ...     August         2
# 1009  La France de Macron est islamophobe, \n@Ersili...     August         1
# 1010  Vendredi 06 Septembre 2024 à 20h35 sur @TF1 : ...     August         0
# 1011  🇵🇸 | 🇮🇱 NEWS - La France, l’Allemagne et le Ro...     August         4
# 1012  ok alors je résume :\n\n- films de merde pour ...     August         0
#
#       Likes country                                        Text_clean1
# 0      2375  France  "Paris France" se traduit en anglais par "Pari...
# 1      6452  France                              French Riviera France
# 2      1326  France  When the Fifth Republic was created, women had...
# 3      6146  France  An unknown troublemaker close to LFI deputies,...
# 4      9311  France  A truly unique charm CR Cloud Screen by Pillow...
# ...     ...     ...                                                ...
# 1008      5  France  A wonderful Olympic fortnight has just come to...
# 1009      1  France  Macron's France is Islamophobic. Ersilia Souda...
# 1010      0  France  Friday, September 6th, 2024 at 8:35 PM on TF1 ...
# 1011      6  France  NEWS France, Germany, and the United Kingdom d...
# 1012     13  France  Ok so let me sum up. Shitty movies for the mos...
#
# [1013 rows x 7 columns]

# %%
# concat all the datasets together

dataset = pd.concat([france_0102_df,france_0305_df, france_0609_df, 
                     england_0102_df, england_0305_df, england_0609_df,
                     usa_0102_df, usa_0305_df, usa_0609_df ], ignore_index = True)

print(dataset.shape)
dataset
# Out:
# (2933, 7)
#                         Username  \
# 0                 Keur Soxna Mai
# 1                      Actu Foot
# 2                          momow
# 3                 Netflix France
# 4                 QuotidienSport
# ...                          ...
# 2928                  The Ledger
# 2929                     NBC DFW
# 2930  PSS International Removals
# 2931                  BC Fencing
# 2932                      KRDO13
#
#                                                    Text     Month  Retweets  \
# 0     Chère communauté,                             ...  February        29
# 1     🚨 𝗟𝗔 𝗙𝗥𝗔𝗡𝗖𝗘 𝗘𝗦𝗧 𝗦𝗔𝗖𝗥𝗘́𝗘 𝗖𝗛𝗔𝗠𝗣𝗜𝗢𝗡𝗡𝗘 𝗗'𝗘𝗨𝗥𝗢𝗣𝗘 𝗗𝗘...   January      2514
# 2     @letheoricien228 Les prix montent, les salaire...   January        11
# 3     Le Cercle des neiges (2024), par J.A. Bayona h...   January       115
# 4     🇫🇷 LA FRANCE EST CHAMPIONNE D’EUROPE 2024 !!!!...   January        74
# ...                                                 ...       ...       ...
# 2928  Coco Gauff is women's flag bearer at Opening C...      July         0
# 2929  As the Paris Olympics are set to open this wee...      July         0
# 2930  With summer just around the corner, beach love...      June         0
# 2931  Ralf Bissdorf led the United States to their f...    August         0
# 2932  The 2024 Summer Games are officially underway!...      July         0
#
#       Likes country                                        Text_clean1
# 0        63  France  Chère communauté                              ...
# 1     27681  France   𝗟𝗔 𝗙𝗥𝗔𝗡𝗖𝗘 𝗘𝗦𝗧 𝗦𝗔𝗖𝗥𝗘𝗘 𝗖𝗛𝗔𝗠𝗣𝗜𝗢𝗡𝗡𝗘 𝗗𝗘𝗨𝗥𝗢𝗣𝗘 𝗗𝗘 𝗛𝗔...
# 2       290  France  letheoricien228 Les prix montent les salaires ...
# 3      1159  France           Le Cercle des neiges 2024 par JA Bayona
# 4       579  France   LA FRANCE EST CHAMPIONNE DEUROPE 2024  JADORE...
# ...     ...     ...                                                ...
# 2928      1     Usa  Coco Gauff is womens flag bearer at Opening Ce...
# 2929      3     Usa  As the Paris Olympics are set to open this wee...
# 2930      0     Usa  With summer just around the corner beach lover...
# 2931      1     Usa  Ralf Bissdorf led the United States to their f...
# 2932      2     Usa  The 2024 Summer Games are officially underway ...
#
# [2933 rows x 7 columns]

# %%
# save dataframe
dataset.to_csv("full_data.csv" , index = False)

# %%
dataset_ini = pd.read_csv("full_data.csv")

dataset_ini["Text_clean1"].replace({"LA FRANCE EST SACREE CHAMPIONNE D'EUROPE DE HAND POUR LA QUATRIEME FOIS 🏆": "france is crowned european handball champion for the fourth time"},
                                  inplace = True)
dataset_ini["Month"] = dataset["Month"]
dataset_ini["Month"].value_counts()
# Out:
# C:\Users\mayen\AppData\Local\Temp\ipykernel_71424\538025063.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset_ini["Text_clean1"].replace({"LA FRANCE EST SACREE CHAMPIONNE D'EUROPE DE HAND POUR LA QUATRIEME FOIS 🏆": "france is crowned european handball champion for the fourth time"},
# Month
# September    1076
# February      523
# May           390
# August        275
# January       199
# July          155
# March         141
# April         111
# June           63
# Name: count, dtype: int64

# %%
dataset_ini
# Out:
#                         Username  \
# 0                 Keur Soxna Mai
# 1                      Actu Foot
# 2                          momow
# 3                 Netflix France
# 4                 QuotidienSport
# ...                          ...
# 2928                  The Ledger
# 2929                     NBC DFW
# 2930  PSS International Removals
# 2931                  BC Fencing
# 2932                      KRDO13
#
#                                                    Text     Month  Retweets  \
# 0     Chère communauté,                             ...  February        29
# 1     🚨 𝗟𝗔 𝗙𝗥𝗔𝗡𝗖𝗘 𝗘𝗦𝗧 𝗦𝗔𝗖𝗥𝗘́𝗘 𝗖𝗛𝗔𝗠𝗣𝗜𝗢𝗡𝗡𝗘 𝗗'𝗘𝗨𝗥𝗢𝗣𝗘 𝗗𝗘...   January      2514
# 2     @letheoricien228 Les prix montent, les salaire...   January        11
# 3     Le Cercle des neiges (2024), par J.A. Bayona h...   January       115
# 4     🇫🇷 LA FRANCE EST CHAMPIONNE D’EUROPE 2024 !!!!...   January        74
# ...                                                 ...       ...       ...
# 2928  Coco Gauff is women's flag bearer at Opening C...      July         0
# 2929  As the Paris Olympics are set to open this wee...      July         0
# 2930  With summer just around the corner, beach love...      June         0
# 2931  Ralf Bissdorf led the United States to their f...    August         0
# 2932  The 2024 Summer Games are officially underway!...      July         0
#
#       Likes country                                        Text_clean1  \
# 0        63  France  Dear community, Our brand KEUR SOXNA MAI is pa...
# 1     27681  France  france is crowned european handball champion f...
# 2       290  France  letheoricien228 Prices are rising, salaries ar...
# 3      1159  France                "The Snow Circle 2024 by JA Bayona"
# 4       579  France  France is the champion of Europe 2024! I love ...
# ...     ...     ...                                                ...
# 2928      1     Usa  Coco Gauff is womens flag bearer at Opening Ce...
# 2929      3     Usa  As the Paris Olympics are set to open this wee...
# 2930      0     Usa  With summer just around the corner beach lover...
# 2931      1     Usa  Ralf Bissdorf led the United States to their f...
# 2932      2     Usa  The 2024 Summer Games are officially underway ...
#
#       count_words
# 0              37
# 1              10
# 2              14
# 3               7
# 4              26
# ...           ...
# 2928           16
# 2929           24
# 2930           29
# 2931           36
# 2932           29
#
# [2933 rows x 8 columns]

# %% [markdown]
# ## Visualization

# %%
# word cloud autre version 
from wordcloud import WordCloud
plt.figure(figsize = (20,20))
wc = WordCloud(max_words = 1000 , width = 1600 , height = 800,
               collocations=False).generate(" ".join(dataset_ini.Text_clean1))
plt.imshow(wc)

# %%
from collections import Counter
all_word = ' '.join([tweet for tweet in dataset_ini["Text_clean1"]]).split()
word_counts = Counter(all_word)

word_counts.most_common((10))
# Out:
# [('the', 3878),
#  ('in', 1945),
#  ('of', 1865),
#  ('to', 1712),
#  ('and', 1330),
#  ('a', 1209),
#  ('for', 1003),
#  ('2024', 896),
#  ('is', 893),
#  ('on', 712)]

# %%
words_sorted
# Out:
# ['the', 'in', 'of', 'to', 'and', 'a', 'for', '2024', 'is', 'on']

# %%
# Obtenir les 10 mots les plus fréquents et leurs comptes
most_common_words = word_counts.most_common(10)
words = [word for word, count in most_common_words]
counts = [count for word, count in most_common_words]

# Trier les données par effectif décroissant
sorted_indices = sorted(range(len(counts)), key=lambda i: counts[i], reverse=True)
words_sorted = [words[i] for i in sorted_indices]
counts_sorted = [counts[i] for i in sorted_indices]

# Créer le graphique
plt.figure(figsize=(10, 6))
plt.bar(words_sorted, counts_sorted)
plt.xlabel('Mots')
plt.ylabel('Fréquence')
plt.title('Les 10 mots les plus fréquents dans les tweets')
plt.show()

# %%
# distribution du nombre de tweets par mois
import seaborn as sns

test2 = dataset_ini[["Month", "Text_clean1"]].groupby("Month").agg({"Text_clean1": 'count'}).sort_values(by = "Text_clean1", ascending = False).reset_index()

plt.figure(figsize = (10,8))
sns.barplot(x = test2.Month, y = test2.Text_clean1)
plt.xlabel("Months")
plt.ylabel("Number of tweets")
plt.title("Number of tweets per Month")
plt.show()

# %%
test2 = dataset_ini[["country", "Text_clean1"]].groupby("country").agg({"Text_clean1": 'count'}).sort_values(by = "Text_clean1", ascending = False).reset_index()

plt.figure(figsize = (10,8))
sns.barplot(x = test2.country, y = test2.Text_clean1)
plt.xlabel("country")
plt.ylabel("Number of tweets")
plt.title("Number of tweets per country")
plt.show()

# %%
def count_word(tweet):
    return len(tweet.split(' '))

dataset_ini["count_words"] = dataset_ini.Text_clean1.apply(count_word)

# representation graphique

plt.figure(figsize = (10, 8))
sns.kdeplot(dataset_ini["count_words"], shade = True, color = "r")
plt.title("Distribution of number of words")
plt.show()
# Out:
# C:\Users\mayen\AppData\Local\Temp\ipykernel_71424\2803190921.py:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataset_ini["count_words"], shade = True, color = "r")

# %%
plt.figure(figsize = (10,8))
sns.kdeplot(data = dataset_ini, x ="count_words", hue = "country",shade = True, common_norm = False )
plt.title("Distribution of word per country")
plt.xlabel("Number of word")
plt.ylabel("Density")
# Out:
# C:\Users\mayen\AppData\Local\Temp\ipykernel_71424\394730181.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data = dataset_ini, x ="count_words", hue = "country",shade = True, common_norm = False )
# C:\Users\mayen\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\mayen\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\mayen\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Text(0, 0.5, 'Density')

# %%
test = dataset_ini[["Month", "count_words"]].groupby("Month").agg({"count_words" : "sum"}).sort_values(by = "count_words", ascending = False).reset_index()

colors = ['#1E7FCB','#74D0F1','#80D0D0','#048B9A'] 
plt.figure(figsize = (10, 8))
plt.pie(test.count_words, labels=test.Month, autopct='%1.1f%%', startangle=140,
       colors = colors)

plt.title("Distribution of Number of words by Month")
plt.show()

# %% [markdown]
# # 2. Topic detection
#
# For this part we gonna select the most topic for 2024
#
# >- Immigration
# >- Aborption
# >- Kylian Mbappe
# >- olympic games
# >- olympic games opening ceremony
# >-European elections
# >- Donald Trump
# >- Dune 2

# %%
openai.api_key = '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'

# %%
def detecter_topic(tweet):
    topics = ["immigration", "abortion","olympic opening ceremony", "olympics games", "donald trump", "emmanuel macron", "cinema"]
    
    prompt = f" this is a tweet : '{tweet}'. determine the best topic among the following topics : {', '.join(topics)}.you can also recommand an other topic but give an answer just with the topic name. don't give a sentence only the topic name "
    
    response = openai.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "you are a topic classifier."},
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content

# %%
dataset["Topics"] = dataset["Text_clean1"].apply(detecter_topic)

# %%
dataset
# Out:
#                         Username  \
# 0                 Keur Soxna Mai
# 1                      Actu Foot
# 2                          momow
# 3                 Netflix France
# 4                 QuotidienSport
# ...                          ...
# 2928                  The Ledger
# 2929                     NBC DFW
# 2930  PSS International Removals
# 2931                  BC Fencing
# 2932                      KRDO13
#
#                                                    Text     Month  Retweets  \
# 0     Chère communauté,                             ...  February        29
# 1     🚨 𝗟𝗔 𝗙𝗥𝗔𝗡𝗖𝗘 𝗘𝗦𝗧 𝗦𝗔𝗖𝗥𝗘́𝗘 𝗖𝗛𝗔𝗠𝗣𝗜𝗢𝗡𝗡𝗘 𝗗'𝗘𝗨𝗥𝗢𝗣𝗘 𝗗𝗘...   January      2514
# 2     @letheoricien228 Les prix montent, les salaire...   January        11
# 3     Le Cercle des neiges (2024), par J.A. Bayona h...   January       115
# 4     🇫🇷 LA FRANCE EST CHAMPIONNE D’EUROPE 2024 !!!!...   January        74
# ...                                                 ...       ...       ...
# 2928  Coco Gauff is women's flag bearer at Opening C...      July         0
# 2929  As the Paris Olympics are set to open this wee...      July         0
# 2930  With summer just around the corner, beach love...      June         0
# 2931  Ralf Bissdorf led the United States to their f...    August         0
# 2932  The 2024 Summer Games are officially underway!...      July         0
#
#       Likes country                                        Text_clean1  \
# 0        63  France  Dear community, Our brand KEUR SOXNA MAI is pa...
# 1     27681  France  LA FRANCE EST SACREE CHAMPIONNE D'EUROPE DE HA...
# 2       290  France  letheoricien228 Prices are rising, salaries ar...
# 3      1159  France                "The Snow Circle 2024 by JA Bayona"
# 4       579  France  France is the champion of Europe 2024! I love ...
# ...     ...     ...                                                ...
# 2928      1     Usa  Coco Gauff is womens flag bearer at Opening Ce...
# 2929      3     Usa  As the Paris Olympics are set to open this wee...
# 2930      0     Usa  With summer just around the corner beach lover...
# 2931      1     Usa  Ralf Bissdorf led the United States to their f...
# 2932      2     Usa  The 2024 Summer Games are officially underway ...
#
#                                  Topics  \
# 0                    European elections
# 1                         Olympic Games
# 2                    european elections
# 3                         Dune Part Two
# 4                        olympics games
# ...                                 ...
# 2928           Olympic Opening Ceremony
# 2929                      Olympic Games
# 2930  Recreational activities or Travel
# 2931                      Olympic Games
# 2932                      Olympic Games
#
#                                     Sentiment                   Topics2
# 0                                     Neutral           emmanuel macron
# 1     The sentiment of the tweet is positive.           emmanuel macron
# 2                                    negative           emmanuel macron
# 3                                     neutral             Dune part two
# 4                                    Positive            olympics games
# ...                                       ...                       ...
# 2928  The sentiment of the tweet is positive.  olympic opening ceremony
# 2929  The sentiment of the tweet is positive.            olympics games
# 2930  The sentiment of the tweet is positive.             Dune part two
# 2931                                 positive            olympics games
# 2932  The sentiment of the tweet is positive.            olympics games
#
# [2933 rows x 10 columns]

# %% [markdown]
# # 3. Sentiment Analysis

# %%
def analyser_sentiment(tweet):
    response = openai.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "you analyze tweets sentiments."},
            {"role": "user", "content": f"what is the sentiment of this tweet ? '{tweet}', answer only with positive, negative or neutral"}
        ]
    )
    return response.choices[0].message.content

# %%
dataset["Sentiment"] = dataset["Text_clean1"].apply(analyser_sentiment)

# %%
dataset
# Out:
#                         Username  \
# 0                 Keur Soxna Mai
# 1                      Actu Foot
# 2                          momow
# 3                 Netflix France
# 4                 QuotidienSport
# ...                          ...
# 2928                  The Ledger
# 2929                     NBC DFW
# 2930  PSS International Removals
# 2931                  BC Fencing
# 2932                      KRDO13
#
#                                                    Text     Month  Retweets  \
# 0     Chère communauté,                             ...  February        29
# 1     🚨 𝗟𝗔 𝗙𝗥𝗔𝗡𝗖𝗘 𝗘𝗦𝗧 𝗦𝗔𝗖𝗥𝗘́𝗘 𝗖𝗛𝗔𝗠𝗣𝗜𝗢𝗡𝗡𝗘 𝗗'𝗘𝗨𝗥𝗢𝗣𝗘 𝗗𝗘...   January      2514
# 2     @letheoricien228 Les prix montent, les salaire...   January        11
# 3     Le Cercle des neiges (2024), par J.A. Bayona h...   January       115
# 4     🇫🇷 LA FRANCE EST CHAMPIONNE D’EUROPE 2024 !!!!...   January        74
# ...                                                 ...       ...       ...
# 2928  Coco Gauff is women's flag bearer at Opening C...      July         0
# 2929  As the Paris Olympics are set to open this wee...      July         0
# 2930  With summer just around the corner, beach love...      June         0
# 2931  Ralf Bissdorf led the United States to their f...    August         0
# 2932  The 2024 Summer Games are officially underway!...      July         0
#
#       Likes country                                        Text_clean1  \
# 0        63  France  Dear community, Our brand KEUR SOXNA MAI is pa...
# 1     27681  France  LA FRANCE EST SACREE CHAMPIONNE D'EUROPE DE HA...
# 2       290  France  letheoricien228 Prices are rising, salaries ar...
# 3      1159  France                "The Snow Circle 2024 by JA Bayona"
# 4       579  France  France is the champion of Europe 2024! I love ...
# ...     ...     ...                                                ...
# 2928      1     Usa  Coco Gauff is womens flag bearer at Opening Ce...
# 2929      3     Usa  As the Paris Olympics are set to open this wee...
# 2930      0     Usa  With summer just around the corner beach lover...
# 2931      1     Usa  Ralf Bissdorf led the United States to their f...
# 2932      2     Usa  The 2024 Summer Games are officially underway ...
#
#                                                  Topics  \
# 0     L'événement décrit dans le tweet semble être l...
# 1     Le sujet le plus proche pour le tweet "LA FRAN...
# 2     Ce tweet pourrait être associé au sujet de l'é...
# 3                                       "Dune part two"
# 4     Ce tweet serait le plus pertinent pour le suje...
# ...                                                 ...
# 2928  Le sujet le plus proche serait "Olympic openin...
# 2929  Le sujet le plus proche pour ce tweet serait "...
# 2930  Le sujet le plus proche du tweet fourni serait...
# 2931       Le sujet le plus proche est "olympic games".
# 2932  Cela concerne les Jeux olympiques et la cérémo...
#
#                                     Sentiment
# 0                                     Neutral
# 1     The sentiment of the tweet is positive.
# 2                                    negative
# 3                                     neutral
# 4                                    Positive
# ...                                       ...
# 2928  The sentiment of the tweet is positive.
# 2929  The sentiment of the tweet is positive.
# 2930  The sentiment of the tweet is positive.
# 2931                                 positive
# 2932  The sentiment of the tweet is positive.
#
# [2933 rows x 9 columns]

# %%
print(dataset["Text_clean1"][1512])

print(dataset["Topics"][1512])

print(dataset["Topics2"][1512])

print(dataset["Sentiment"][1512])
# Out:
# England will hoard all these players give them a false sense of hope then still be playing Kalvin Phillips and Jordan Henderson at major tournaments
# european elections
# olympics games
# negative

# %%
dataset.to_csv("full_data2.csv" , index = False)

# %%
dataset["Topics"][3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dataset["Topics"][3]
#
# NameError: name 'dataset' is not defined

# %% [markdown]
# # Inspection

# %%
dataset_fin = pd.read_csv("full_data2.csv")
dataset_fin.head()
# Out:
#          Username                                               Text  \
# 0  Keur Soxna Mai  Chère communauté,                             ...
# 1       Actu Foot  🚨 𝗟𝗔 𝗙𝗥𝗔𝗡𝗖𝗘 𝗘𝗦𝗧 𝗦𝗔𝗖𝗥𝗘́𝗘 𝗖𝗛𝗔𝗠𝗣𝗜𝗢𝗡𝗡𝗘 𝗗'𝗘𝗨𝗥𝗢𝗣𝗘 𝗗𝗘...
# 2           momow  @letheoricien228 Les prix montent, les salaire...
# 3  Netflix France  Le Cercle des neiges (2024), par J.A. Bayona h...
# 4  QuotidienSport  🇫🇷 LA FRANCE EST CHAMPIONNE D’EUROPE 2024 !!!!...
#
#       Month  Retweets  Likes country  \
# 0  February        29     63  France
# 1   January      2514  27681  France
# 2   January        11    290  France
# 3   January       115   1159  France
# 4   January        74    579  France
#
#                                          Text_clean1  \
# 0  Dear community, Our brand KEUR SOXNA MAI is pa...
# 1  LA FRANCE EST SACREE CHAMPIONNE D'EUROPE DE HA...
# 2  letheoricien228 Prices are rising, salaries ar...
# 3                "The Snow Circle 2024 by JA Bayona"
# 4  France is the champion of Europe 2024! I love ...
#
#                       Topics Sentiment          Topics2
# 0         European elections   neutral  emmanuel macron
# 1              Olympic Games  positive  emmanuel macron
# 2  economic issues in France  negative  emmanuel macron
# 3              Dune Part Two   neutral    Dune part two
# 4             olympics games  positive   olympics games

# %%
list(dataset_fin["Topics"].value_counts().items())
# Out:
# [('European elections', 361),
#  ('Olympic Games', 223),
#  ('european elections', 191),
#  ('immigration', 152),
#  ('Emmanuel Macron', 136),
#  ('European Elections', 124),
#  ('Dune part two', 122),
#  ('Olympics Games', 119),
#  ('olympics games', 110),
#  ('emmanuel macron', 78),
#  ('olympic games', 57),
#  ('Olympics games', 54),
#  ('Immigration', 45),
#  ('sports', 42),
#  ('European elections.', 40),
#  ('Olympic games', 37),
#  ('Abortion', 25),
#  ('Dune part two.', 23),
#  ('Dune Part Two', 17),
#  ('Cricket', 16),
#  ('cricket', 16),
#  ('Olympic Opening Ceremony', 14),
#  ('european elections.', 13),
#  ('olympic opening ceremony', 12),
#  ('education', 10),
#  ('Emmanuel Macron.', 10),
#  ('Immigration.', 9),
#  ('immigration.', 8),
#  ('climate change', 8),
#  ('European Elections.', 8),
#  ('Olympic Games.', 7),
#  ('elections', 6),
#  ('Travel and Tourism', 6),
#  ('Olympics Games.', 5),
#  ('economy', 5),
#  ('Olympic opening ceremony', 5),
#  ('international relations', 5),
#  ('emmanuel macron.', 5),
#  ('olympics games.', 4),
#  ('Olympic games.', 4),
#  ('weather', 4),
#  ('Presidential Election', 4),
#  ('Sports', 4),
#  ('recommend an other topic', 4),
#  ('healthcare', 4),
#  ('environmental issues', 4),
#  ('2024 US Presidential Election', 4),
#  ('European Football', 4),
#  ('Weather and Climate', 3),
#  ('fashion', 3),
#  ('soccer', 3),
#  ('weather and climate', 3),
#  ('Olympics games.', 3),
#  ('music', 3),
#  ('rugby', 3),
#  ('2024 presidential election', 3),
#  ('COVID-19 pandemic', 3),
#  ('Eurovision Song Contest', 3),
#  ('Fashion and Style', 3),
#  ('technology', 2),
#  ("women's rights", 2),
#  ('extreme weather', 2),
#  ('Olympic opening ceremony.', 2),
#  ('Presidential Polling', 2),
#  ('- Dune part two', 2),
#  ('Extreme Weather Events', 2),
#  ('Fashion', 2),
#  ('economic growth', 2),
#  ('US Presidential Election ', 2),
#  ('No relevant topic matches the tweet provided.', 2),
#  ('environment', 2),
#  ('US Politics', 2),
#  ('Cricket (INDvENG)', 2),
#  ('Weather & Climate', 2),
#  ('European Football Transfers', 2),
#  ('Topic: Emmanuel Macron', 2),
#  (' european elections', 2),
#  ('natural disasters', 2),
#  ('Euro 2024', 2),
#  ('Dune Part Two.', 2),
#  ('food and dining', 2),
#  ('football', 2),
#  ('Topic: Olympics Games', 2),
#  ('ADHD', 2),
#  ('Abortion.', 2),
#  ('Olympic closing ceremony', 2),
#  ('Concerts', 2),
#  ('Healthcare', 2),
#  ('topic: Dune part two', 2),
#  ('government shutdown', 2),
#  ('The best topic for this tweet is "immigration."', 2),
#  ('Travel and tourism', 2),
#  ('Climate Change', 2),
#  ('sports.', 2),
#  ('Fashion.', 1),
#  ('Food Security', 1),
#  ('None of the provided topics are the best fit for the tweet. The most relevant topic to classify this tweet under would be "Rants about English football/soccer."',
#   1),
#  ('Weather Forecast', 1),
#  ('European football club and upcoming season.', 1),
#  ('english cricket', 1),
#  ('craft beer', 1),
#  ('housing and tenant rights', 1),
#  ('other topic: cricket', 1),
#  ('There is no direct relevance between the tweet and the topics provided. Therefore, I recommend the topic: Sports.',
#   1),
#  ('The best topic for the tweet provided is: Dune part two', 1),
#  ('Donna Summer and laser light shows during the Disco Era would best fit under the topic of Donna Summer or music history.',
#   1),
#  ('The best topic for the tweet provided is "immigration".', 1),
#  ('None of the given topics match the content of the tweet. \nAdditional topic recommendation: Football/Soccer',
#   1),
#  ('Sport and Physical Education', 1),
#  ('None of the given topics are the best fit for the tweet provided. However, a potential suitable topic could be "Social Media Relationships."',
#   1),
#  ('No relevant topic found among the provided options.', 1),
#  ('Best summer of my life (personal experience)', 1),
#  ('Cricket - Englands Test summer', 1),
#  ('unrelated to any of the listed topics', 1),
#  ('None of the given topics are the best fit for the tweet provided. The best topic would be "Sports."',
#   1),
#  ('State of Bazball', 1),
#  ('European football/soccer', 1),
#  ('Seasons and Climate', 1),
#  ('fashion advertising', 1),
#  ('Covid-19 pandemic', 1),
#  ('Sorry, but none of the provided topics seem to be the best fit for the tweet you shared. Based on the content of the tweet, a more suitable topic could be "weather and climate humor."',
#   1),
#  ('None of the provided topics fully align with the tweet. An alternate topic suggestion is Weather and Climate.',
#   1),
#  ('politics', 1),
#  ('The best topic for the tweet is "international relations."', 1),
#  ('economic policy', 1),
#  ('topic: olympic games', 1),
#  ('African Leadership', 1),
#  ('Total Solar Eclipse on April 8th 2024', 1),
#  ('The best topic for this tweet would be: national security.', 1),
#  ('Recommanded topic: Education', 1),
#  ('The best topic for the tweet provided is "technology careers and National Engineers Week."',
#   1),
#  ('embassy operations', 1),
#  ('Among the provided topics, the best match for the tweet is "Olympic Games."',
#   1),
#  ('The best topic for this tweet is: Medical Education and Training', 1),
#  ('Accidents', 1),
#  ('Business and Pharmaceuticals', 1),
#  ('Subpoena investigation.', 1),
#  ('None of the provided topics match the content of the tweet. I recommend the topic: International Relations.',
#   1),
#  ('Donald J Trump', 1),
#  ('Topic: U.S. Politics', 1),
#  ('Election2020', 1),
#  ("The best topic for the tweet 'Mapped The Population of US States Compared with Countries' would be immigration.",
#   1),
#  ('US politics', 1),
#  ('None of the provided topics align well with the content of the tweet. \nI recommend the topic "Music concerts".',
#   1),
#  ('None of the specified topics seem to be the best fit for this tweet. An appropriate topic could be "Football/Sports" or "World Cup".',
#   1),
#  ('health and pandemics', 1),
#  ('relocation', 1),
#  ('vacation/travel', 1),
#  ('Extreme Weather/Emergency Preparedness', 1),
#  ('The best topic for the tweet "Make sure you enjoy the last little bit of summer" would be "Dune part two".',
#   1),
#  ('Political upheaval', 1),
#  ('US presidential election ', 1),
#  ('Kpop industry', 1),
#  ('COVID-19 updates.', 1),
#  ('current political events', 1),
#  ('American Politics', 1),
#  ('College Football', 1),
#  ('Donald Trump reelection', 1),
#  ('2024 Presidential Election', 1),
#  ('The best topic for this tweet is "Immigration."', 1),
#  ('HIV Prevention.', 1),
#  ('None of the given topics would be the best fit for the tweet provided. The recommended topic based on the tweet would be "weather"',
#   1),
#  ('WSL transfer news', 1),
#  ('Euro 2024 squad announcement', 1),
#  ('Football Transfer Rumors', 1),
#  ('hate speech on social media', 1),
#  ('European football transfer rumors', 1),
#  ('Victorian era.', 1),
#  ('Weather and seasons.', 1),
#  ('Sports (Olympics games)', 1),
#  ('European football gossip', 1),
#  ('The best topic for this tweet is "Olympics games".', 1),
#  ('Race and Education.', 1),
#  ('weather or climate', 1),
#  ('Fashion and luxury goods.', 1),
#  ('I recommend the topic of European elections.', 1),
#  ('Football Transfers', 1),
#  ('Weather', 1),
#  ('study abroad opportunities', 1),
#  ('Weather and climate.', 1),
#  ('Study Abroad opportunities.', 1),
#  ('ENGvPAK', 1),
#  ('Sports (specifically soccer/football)', 1),
#  ('EURO2024 Football Tournament', 1),
#  ("The best topic for this tweet is 'Olympic games.'", 1),
#  ('Cricket International Matches.', 1),
#  ('I recommend the topic of **sports** based on the tweet provided.', 1),
#  ('The best topic for the tweet provided is "Olympics Games."', 1),
#  ('Euro 2024 squad announcement.', 1),
#  ('Recommended Topic: Entertainment & Celebrity Events', 1),
#  ('Industry Events', 1),
#  ('- Sports: T20 World Cup and T20I series against Pakistan', 1),
#  ('Health and mortality.', 1),
#  ('European football.', 1),
#  ('Sports and Football.', 1),
#  ('Football', 1),
#  ('Rugby League - Wayne Bennett and Dolphin relocation to Sydney.', 1),
#  ('The best topic for the tweet is "Olympic Games."', 1),
#  ('Cricket24 PatchUPDATE', 1),
#  ('New England Patriots football team', 1),
#  ('Music Tour', 1),
#  ('Police brutality and law enforcement.', 1),
#  ('Cat lovers / Pets', 1),
#  ('None of the given topics align closely with the content of the tweet. Another suitable topic would be "Weather and Climate"',
#   1),
#  ('housing and tenants', 1),
#  ('Best Topic: Dune part two', 1),
#  ('recreational activities', 1),
#  ('Cricket/T20 World Cup', 1),
#  ('sports and football', 1),
#  ('Dierks Bentley concert', 1),
#  ('The best topic for this tweet is "European elections"', 1),
#  ('none of the provided topics align with the content of the tweet.', 1),
#  ('Studying abroad', 1),
#  ('None of the provided topics seem relevant to the tweet "New England summer dream." I recommend the topic "Travel and tourism."',
#   1),
#  ('The best topic for the tweet provided is "Immigration."', 1),
#  ('transfer market', 1),
#  ('Hottest summer in recorded history', 1),
#  ('Israel-Palestine Conflict', 1),
#  ('Environment and Conservation', 1),
#  ('Recommendation: Cricket\n\nBest Topic: Sports (specifically Cricket)', 1),
#  ('agriculture', 1),
#  ('sports (football/ soccer)', 1),
#  ('environment and conservation', 1),
#  ('apprenticeship', 1),
#  ('Extreme weather and climate events', 1),
#  ('Based on the tweet provided, the best topic among the options is not clearly related. I recommend the topic of "TV schedule".',
#   1),
#  ('COVID-19 resurgence in the USA.', 1),
#  ('soccer/transfers', 1),
#  ('European travel and leisure.', 1),
#  ('The most relevant topic for the tweet provided is "European elections."',
#   1),
#  ('European football transfer news', 1),
#  ('Recommended Topic: Sponsorship Partnerships', 1),
#  ('The best topic would be "Anti-racism workshop"', 1),
#  ('Sports Transfer News', 1),
#  ('None of the provided topics are the best fit for the tweet. Another potential topic could be "Nature and Environment."',
#   1),
#  ('Europan Elections', 1),
#  ('Transfer News', 1),
#  ('The best topic for the tweet would be "olympic games."', 1),
#  ('other topic: sports or baseball', 1),
#  ('other topic: sports', 1),
#  ('European travel and vacation plans.', 1),
#  ('The best topic for the tweet would be "New England summer".', 1),
#  ('No relevant topic is directly related to the tweet provided.', 1),
#  ('COVID-19 pandemic.', 1),
#  ('The best topic for this tweet would be "weather."', 1),
#  ('Joe Biden is the best president in the USA - Topic: Emmanuel Macron', 1),
#  ('No clear match with the given topics. Another recommended topic is "U.S. Politics".',
#   1),
#  ('UNDPCareers', 1),
#  ('marketing and advertising', 1),
#  ('Presidential Election (Biden vs. Trump)', 1),
#  ('Presidential election.', 1),
#  ('Presidential Election ', 1),
#  ('The best topic for the tweet you provided is "Presidential Polling."', 1),
#  ('Presidential Election Polling', 1),
#  ('The best topic for the tweet is "United States", discussing the current situation or events related to the country.',
#   1),
#  ('travel and tourism.', 1),
#  ('New recommended topic: Advertising and marketing', 1),
#  ('U.S. politics', 1),
#  ('The best topic for this tweet would be "Dune part two".', 1),
#  ('COVID-19 developments', 1),
#  ('Other topic: Business and International Trade.', 1),
#  ('Education Abroad', 1),
#  ('Art & Culture', 1),
#  ('Rugby development in the United States', 1),
#  ('Trump 2024', 1),
#  ('Other topic: 2024 United States Presidential Election', 1),
#  ('Economic comparison between the USA and Japan', 1),
#  ('Joe Biden vs. Citizen Trump in the next US election.', 1),
#  ('Other Topic: Travel and Attractions', 1),
#  ('No clear topic from the list fits the given tweet. Another possible topic could be "advertising and marketing awards".',
#   1),
#  ('2024 Election', 1),
#  ('The best topic for the tweet provided is National Parks.', 1),
#  ('global power rankings', 1),
#  ('US presidential election', 1),
#  ('foreign relations', 1),
#  ('Gun control & Biden Administration', 1),
#  ('USA Presidential Election ', 1),
#  ('military and veterans', 1),
#  ('Education overseas.', 1),
#  ('internship opportunities', 1),
#  ('The best topic for the tweet is "US Army and Memorial Day Remembrance".',
#   1),
#  ('Anti-Semitism and US-Israel Relations.', 1),
#  ('business/ advertising', 1),
#  ('None of the provided topics seem to align with the content of the tweet. An additional relevant topic could be "Advertising Agencies Rankings".',
#   1),
#  ('economic summit', 1),
#  ('The best topic for this tweet is "American politics".', 1),
#  ('U.S. Presidential Election', 1),
#  ('weather & climate.', 1),
#  ('The best topic for the tweet would be "olympics games"', 1),
#  ('politics ', 1),
#  ('topic: Travel / Airports', 1),
#  ('international trade', 1),
#  ('Extreme weather/heat wave.', 1),
#  ('recommended topic: Weather', 1),
#  ('The best topic for the tweet is "entertainment/pop culture"', 1),
#  ('Recommended topic: Politics', 1),
#  ('Summer Showdown and Copa America 2024', 1),
#  ('Astrology', 1),
#  ('Climate change and global warming.', 1),
#  ('Other Topic: Sports (Wrestling/Entertainment)', 1),
#  ('Wrestling', 1),
#  ('climate and weather', 1),
#  ("Katy Perry's comeback song and potential claim for 2024's song of the summer falls under the topic of music and entertainment.",
#   1),
#  ('WWE Pay-Per-View Schedule', 1),
#  ('Sorry, none of the given topics match the content of the tweet. The best topic for the tweet would be "music/popular songs."',
#   1),
#  ('weather and natural disasters', 1),
#  ('topic: music.', 1),
#  ('None of the provided topics seem to be the best fit for the tweet you shared. \nRecommended topic: Weather/Temperature.',
#   1),
#  ('Other topic: Event planning', 1),
#  ('weather & climate', 1),
#  ('There is no clear connection between the tweet and any of the provided topics. Another potential relevant topic could be "seasons" as the tweet pertains to the end of summer in September.',
#   1),
#  ('energy and environmental policy', 1),
#  ('Entertainment celebrity and music.', 1),
#  ('No clear match found among the specified topics. Another potential topic could be "Music tours and concerts."',
#   1),
#  ('Concerts, Entertainment', 1),
#  ('Entertainment (concerts)', 1),
#  ('None of the listed topics are the best fit for the given tweet. \n\nRecommended topic: Seasons and Weather',
#   1),
#  ('none of the provided topics are the best match for the tweet. The best topic would be "cryptic message or conspiracy theories".',
#   1),
#  ('Other Topic: Music & Entertainment', 1),
#  ('Seasons and lifestyle', 1),
#  ('The best topic for the tweet is: National celebrations.\n\nAnother topic recommendation: Summer activities.',
#   1),
#  ('Topic: Love Island USA premiere', 1),
#  ('Concerts.', 1),
#  ('Love Island USA', 1),
#  ('2024 Summer Olympics', 1),
#  ('Topic: Extreme Weather Events', 1),
#  ('Weather Forecasting', 1),
#  ('Other Topic: Music/Pop Culture', 1),
#  ('Weather and ClimatecreateQuery.getData is the most suitable topic for this tweet.',
#   1),
#  ('Topic: Olympic Games', 1),
#  ('Holidays and Memorial Day', 1),
#  ('Recommending an alternate topic: Celebrity Reactions to Political Events',
#   1),
#  ('Israeli-Palestinian conflict', 1),
#  ('United States Space Force', 1),
#  ('The best topic for the tweet you provided is U.S. politics.', 1),
#  ('The best topic for this tweet is: US Economy', 1),
#  ('Best museums across the United States.', 1),
#  ('Self-publishing', 1),
#  ('None of the provided topics match the content of the tweet. I would recommend the topic of "sustainable agriculture" as a more fitting option.',
#   1),
#  ('patents', 1),
#  ('The best topic from the given list is "immigration".', 1),
#  ('US debt and budget deficit', 1),
#  ('international cooperation', 1),
#  ('Pop Culture', 1),
#  ('US Congress Funding Deal', 1),
#  ('NFL Football', 1),
#  ('Travel & Tourism', 1),
#  ('The best topic for the tweet is: Music museums', 1),
#  ('science museums', 1),
#  ('Economic trends and outlook.', 1),
#  ('North Korea diplomacy', 1),
#  ('- Olympic Games', 1),
#  ('Competitions and Grants', 1),
#  ('entrepreneurship', 1),
#  ('The best topic for the tweet you shared would be "Education Scholarships."',
#   1),
#  ('health crisis', 1),
#  ('The best topic for this tweet is "Drought Preparedness Act".', 1),
#  ('2024 Democratic Primary Ballot', 1),
#  ('- Political Crisis in the United States', 1),
#  ('None of the provided topics are the best fit for the tweet. Another topic that aligns better with the content of the tweet is: Political Comparisons.',
#   1),
#  ('Political Elections.', 1),
#  ('Weather/climate.', 1),
#  ('wildfires', 1),
#  ('Political beliefs and priorities', 1),
#  ('Job opportunities', 1),
#  ('Agriculture & Livestock', 1),
#  ('terrorism', 1),
#  ('Recommended Topic: Business and Economic Development', 1),
#  ('employment and workforce trends', 1),
#  ('geopolitics', 1),
#  ('child trafficking', 1),
#  ('Topic: immigration', 1),
#  ('2024 National GE - Presidential Election', 1),
#  ('aviation', 1),
#  ('USA-Kenya military partnership', 1),
#  ('I would recommend the topic of "Olympic Games" for this tweet.', 1),
#  ('Dengue Outbreaks', 1),
#  ('The best topic would be international time zones.', 1),
#  ('Cars and automotive industry.', 1),
#  ('Recommended topic: Olympic Games', 1),
#  ('study abroad', 1),
#  ('cryptocurrency', 1),
#  ('Extreme weather / Heatwaves', 1),
#  ('business and technology', 1),
#  ('import/export trade', 1),
#  ('4th of July Celebrations.', 1),
#  ('student loans', 1),
#  ('COVID-19', 1),
#  ('- Politics', 1),
#  ('Economic Comparisons', 1),
#  ('Ethiopian Ambassador Resignation.', 1),
#  ('Memorial Day Tribute 2024 would be best categorized under "holidays and observances".',
#   1),
#  ('military', 1),
#  ('Travel and Tourism.', 1),
#  ('USElection2024', 1),
#  ('The best topic among the given choices for the tweet is "USPS concerns".',
#   1),
#  ('The best topic for this tweet would be "Emmanuel Macron."', 1),
#  ('The best topic for the tweet is "security or defense."', 1),
#  ('European politics', 1),
#  ('American Economy', 1),
#  ('energy and natural resources', 1),
#  ('scholarships', 1),
#  ('Recommend a topic: Education \n\nBest fit topic: Education', 1),
#  ('wedding exhibitions.', 1),
#  ('AAPI Heritage Month', 1),
#  ('Tech and Innovation', 1),
#  ('USA Music Festivals', 1),
#  ('No relevant topic matching the tweet is present among the options provided.',
#   1),
#  ('Memorial Day', 1),
#  ('For the tweet provided, the best topic would be "weather" as it discusses the summer heat and staying hydrated.',
#   1),
#  ('None of the provided topics match the content of the tweet. An appropriate topic for the tweet would be "Music Tour Dates."',
#   1),
#  ('astrology', 1),
#  ('topic: US national debt', 1),
#  ('4th of July celebrations in the USA', 1),
#  ('Recommended Topic: Business/Corporate Achievements', 1),
#  ('community events', 1),
#  ('European football / sports', 1),
#  ('[No Relevant Topic Identified]', 1),
#  ('sports betting', 1),
#  ('The best topic for this tweet is censorship.', 1),
#  ('Gaza Massacres', 1),
#  ('Sports - Soccer', 1),
#  ('None of the topics listed are relevant to the tweet. Another relevant topic could be "Pets and Pet Care."',
#   1),
#  ('family and relationships', 1),
#  ('None of the provided topics match the content of the tweet. \nA more suitable topic would be: Video Games.',
#   1),
#  ('American politics', 1),
#  ('Possible topic: Sports (French national team player being booed)', 1),
#  ('European History.', 1),
#  ('No relevant topic matches the content of the tweet provided.', 1),
#  ('Other recommended topic: Crime and Criminal Justice.', 1),
#  ('None of the pre-suggested topics seem directly relevant to the content of the tweet provided. I would recommend the following topic as the most appropriate: Justice and crime.',
#   1),
#  ('Kpop', 1),
#  ('Other topic: Social media/communication', 1),
#  ('Transgender rights', 1),
#  ('European Energy Policy', 1),
#  ('Haiti Economic Situation', 1),
#  ('history', 1),
#  ('violence against women.', 1),
#  ('None of the provided topics seem relevant to the tweet. An alternative topic could be "travel adventures."',
#   1),
#  ('None of the given topics match the content of the tweet.', 1),
#  ('EURO 2024 squad announcement', 1),
#  ('employment opportunities', 1),
#  ('Eurovision 2024', 1),
#  ('None of the provided topics seem to be the best fit for the tweet mentioned. \n\nRecommendation: Technology & Gaming',
#   1),
#  ('Recommended topic: Entertainment\n', 1),
#  ('Food Safety', 1),
#  ('Recommend an other topic: Tourism', 1),
#  ('Hamas', 1),
#  ('French Riviera France - tourism', 1),
#  ('The best topic for the tweet is "immigration."', 1),
#  ('Difference between Pool culture in France and Poland.', 1),
#  ('The best topic for this tweet is "Olympic games."', 1),
#  ('Traffic accidents', 1),
#  ('military and nationalism', 1),
#  ('Other Topic: Human Interest\n', 1),
#  ('future careers', 1),
#  ('anti-semitism', 1),
#  ('corruption', 1),
#  ('The best topic for the tweet is "European elections."', 1),
#  ('Sports (Ligue 1)', 1),
#  ('The best topic for the tweet \'"Labourious"\' would be "Dune part two."',
#   1),
#  ('cultural appreciation', 1),
#  ('Brain Health/Memory Stimuation', 1),
#  ('Student living conditions & student welfare', 1),
#  ('eSports and Gaming', 1),
#  ('agriculture and food safety.', 1),
#  ('No specific topic from the options provided matches the content of the tweet.',
#   1),
#  ('This tweet is best classified under the topic of "Traffic Accidents/Crashes".',
#   1),
#  ('This tweet does not directly relate to any of the given topics. An alternative topic could be "personal relationships."',
#   1),
#  ('None of the provided topics directly align with the content of the tweet. I recommend the topic "Media Ethics" as a relevant category for discussing the portrayal of nudity on public broadcast platforms.',
#   1),
#  ('The best topic for this tweet is "internet privacy and freedom of expression."',
#   1),
#  ('Sustainable architecture.', 1),
#  ('Arson/vandalism on a church in France.', 1),
#  ('none of the mentioned topics are the best fit for the tweet. I recommend the topic "music industry".',
#   1),
#  ('corruption.', 1),
#  ('The best topic among the ones provided is "european elections."', 1),
#  ('The best topic for this tweet is political ideology.', 1),
#  ('Elon Musk', 1),
#  ('Olympic Opening Ceremony.', 1),
#  ('None of the provided topics match the content of the tweet. The suggested topic for this tweet is "tragedy" as it discusses the tragic death of Karina Pritika during an anti-Semitic massacre.',
#   1),
#  ('Non-English Events.', 1),
#  ('Crime and legal issues.', 1),
#  ('The best topic for this tweet is "European elections."', 1),
#  ('incorrect topic', 1),
#  ('Geopolitics', 1),
#  ('The best topic for the tweet \'"Veran dressed for winter"\' would be "European elections."',
#   1),
#  ('stock market investing.', 1),
#  ('child abuse', 1),
#  ('Human rights and activism', 1),
#  ('abuse and sexual assault', 1),
#  ('Bridgerton Season 4', 1),
#  ('racism and intolerance', 1),
#  ('pension systems.', 1),
#  ('None of the provided topics are relevant to the tweet.', 1),
#  ('technology/sponsorship', 1),
#  ('Soccer/football', 1),
#  ('sports - specifically related to soccer/football.', 1),
#  ('Family Album AstroBot would best fit under the topic of "Dune part two".',
#   1),
#  ('crime and justice', 1),
#  ('olympic Games', 1),
#  ('social activism', 1),
#  ('Topic: Paris 2024 Olympics', 1),
#  ('senegal politics', 1),
#  ('No relevant topic found in the provided tweet.', 1),
#  ('Topic: Mobile healthcare initiatives', 1),
#  ('animal rights', 1),
#  ('Devoxx France 2024.', 1),
#  ('Rugby.', 1),
#  ('Weather and natural disasters.', 1),
#  ('The best topic among the given options is "Dune part two".', 1),
#  ('NFL Draft', 1),
#  ('The best topic for this tweet would be "Olympic Games."', 1),
#  ('Recommended topic: LGBTQ+ rights & education.', 1),
#  ('Art and Culture', 1),
#  ('Media and journalism', 1),
#  ('Fashion and Beauty', 1),
#  ('TXT_2024DREAMWEEK', 1),
#  ('regulation of AI', 1),
#  ("The best topic for the tweet 'NEWS 240227 Quizzes/games have been posted on the Weverse fancafé 1 TXT_2024DREAMWEEK 2024txt TXT_bighit' is entertainment (specifically related to TXT_2024DREAMWEEK and TXT_bighit).",
#   1),
#  ('Esports', 1),
#  ('Six Nations Tournament.', 1),
#  ('Drama television series.', 1),
#  ('2024 US Presidential Elections', 1),
#  ('Video Games', 1),
#  ('recommendation: television and entertainment', 1),
#  ('Rugby or sports.', 1),
#  ('Recommended Topic: International Summit/Conference', 1),
#  ('economic issues in France', 1),
#  ('It seems that the best topic for the tweet you provided is "Dune part two."',
#   1),
#  ('None of the listed topics align with the tweet provided.', 1),
#  ('Dior Fashion Show', 1),
#  ('None of the provided topics seem to be directly relevant to the tweet you shared.  \nAn alternative topic could be "Infrastructure development."',
#   1),
#  ('The best topic for the tweet is "true crime TV series."', 1),
#  ('Pokemon GO Event - Charged-Up Study Day', 1),
#  ('sports (2024 Six Nations tournament)', 1),
#  ("The best topic for the tweet 'Lorient Nantes Merlus Ultras Saturday, February 24, 2024 MU95' would be the European Elections.",
#   1),
#  ('rugby - sports', 1),
#  ('EHFEuro2024', 1),
#  ('Six Nations rugby match between XV de France and Italy', 1),
#  ('TV shows and streaming content', 1),
#  ('TV shows and movie releases.', 1),
#  ('Best topic: Ranking of most pleasant cities in France', 1),
#  ('BZW Wrestling event', 1),
#  ('Oscars and Foreign Films', 1),
#  ('AFCON2024', 1),
#  ('Hockey injuries', 1),
#  ('None of the given topics directly align with the content of the tweet. It seems that the tweet is discussing the depth and strength of the France national football team. Therefore, the best topic would be "Olympic Games" as it relates to sports and features national teams competing against each other.',
#   1),
#  ('EURO2024', 1),
#  ('- Olympic Games.', 1),
#  ('None of the provided topics seem relevant based on the tweet content. An additional topic that could be suitable is "K-pop bands."',
#   1),
#  ('sports and gaming', 1),
#  ('European events', 1),
#  ('topic: Olympics games', 1),
#  ('Incorrect Information/Conspiracy Theory', 1),
#  ('Entertainment (TOP30 actors and actresses by reputation in May 2024)', 1),
#  ('Recommended topic: Social media\n\nExplanation: The tweet is discussing a social media update about DOHOON sharing photos on Instagram.',
#   1),
#  ('Recommended Topic: International Partnerships.', 1),
#  ('Oscars 2024', 1),
#  ('travel and tourism', 1),
#  ('theater', 1),
#  ('- Justice and Legal System', 1),
#  ('deeptech events', 1),
#  ('none of the provided topics fit the content of the tweet. So, the recommended topic is: Sports.',
#   1),
#  ('None of the provided topics align with the content of the tweet. A more appropriate topic would be "Obituary."',
#   1),
#  ('eurovision', 1),
#  ('awards and honors', 1),
#  ('Neither of the provided topics align with the content of the tweet. A more appropriate topic could be "Sports Events Promotion."',
#   1),
#  ('Sejong University event', 1),
#  ('- EURO2024', 1),
#  ('Air transportation & airlines', 1),
#  ('Ramadan calendar', 1),
#  ('Beauty', 1),
#  ('The best topic among the options provided is "Emmanuel Macron."', 1),
#  ('public transportation', 1),
#  ('fanbase partnership', 1),
#  ('none of the provided topics seem to be related to the tweet.', 1),
#  ("Recommended topic: Women's sports", 1),
#  ('European basketball', 1),
#  ('No relevant topic matches the given tweet.', 1),
#  ('Recommended topic: Careers and Internships', 1),
#  ('Recommended Topic: Anime/Promotion of Anime Series', 1),
#  ('none of the given topics match the content provided in the tweet. A relevant topic could be "K-pop" in this context.',
#   1),
#  ('corruption and abuse of power', 1),
#  ('Paris Fashion Week', 1),
#  ('No Matches.', 1),
#  ('Euro 2024 Football Tournament', 1),
#  ('terrorism in Europe', 1),
#  ('missing person case', 1),
#  ('economic inequality', 1),
#  ('Based on the tweet provided, the best topic classification would be "politics."',
#   1),
#  ('Princess Anne and Motor Neuron Disease Association Fundraiser', 1),
#  ('The best topic for the tweet \'"Poor us"\' would be "European elections".',
#   1),
#  ('movie reviews', 1),
#  ('European Championships', 1),
#  ('European Football.', 1),
#  ('Cricket.', 1),
#  ('lack of information', 1),
#  ('birds nature wildlife', 1),
#  ('No relevant topic matches the content of the tweet. Another suggested topic: Gaming events.',
#   1),
#  ('machine technology', 1),
#  ('Education', 1),
#  ('British Vogue And Tiffany amp Co Celebrate Fashion And Film Party 2024', 1),
#  ('Forestry', 1),
#  ('COVID-19 statistics.', 1),
#  ('scandal', 1),
#  ('None of the topics provided match the content of the tweet. The most relevant topic would be "Music Events."',
#   1),
#  ('Topics: healthcare and professional decision-making', 1),
#  ('Rugby recruiting', 1),
#  ('Public Health', 1),
#  ('Environmental Sustainability', 1),
#  ("Jennifer Tioseco's Instagram story", 1),
#  ('Blockchain and cryptocurrency technologies.', 1),
#  ('The best topic for the tweet "\'I love it\'" would be Dune part two.', 1),
#  ('There is no direct correlation between the tweet "It\'s going well" and the provided topics. I would recommend the topic of "general well-being" as a suitable alternative.',
#   1),
#  ('French politics', 1),
#  ('Not a match for any of the given topics. An alternative topic could be "Social media engagement".',
#   1),
#  ('The best topic for the tweet is "European elections".', 1),
#  ('No appropriate topic matches the content of the tweet.', 1),
#  ('shopping & consumer products', 1),
#  ('None of the provided topics are a perfect fit for this tweet. An alternative topic could be "sports and entertainment."',
#   1),
#  ('None of the given topics seem to be the most relevant for the tweet provided. A more suitable topic could be "K-pop" due to the mention of JIANA and the fans of YOUNGPOSSE.',
#   1),
#  ('None of the provided topics seem to be the best fit for the tweet mentioned. Instead, the best topic for the tweet would be "technology and humor."',
#   1),
#  ('European History', 1),
#  ('Tarot Reading', 1),
#  ('None of the provided topics seem to be relevant to the tweet. Another topic that could be more related to the tweet is "K-pop" as the tweet mentions a person named JIEUN posting pictures.',
#   1),
#  ('Youngposse ', 1),
#  ('European football transfers.', 1),
#  ('Antiquities and Cultural Heritage', 1),
#  ('None of the given topics are relevant to the tweet. An appropriate topic would be "Sports - Soccer"',
#   1),
#  ('None of the given topics seem to be a direct match for the tweet you provided. An alternative topic could be: solidarity/community support.',
#   1),
#  ('Other: Sports and Sports Leagues', 1),
#  ('women empowerment', 1),
#  ('The best topic for this tweet is "social media or personal relationships".',
#   1),
#  ('american football', 1),
#  ('healthcare and dentistry', 1),
#  ('health and smoking', 1),
#  ('farming and agriculture', 1),
#  ('Indian Cricket / Sports', 1),
#  ('NFL and sports.', 1),
#  ('VisitLancashire VisitEngland', 1),
#  ('jurgen klopp, liverpool, european elections', 1),
#  ('Adventist History Tour', 1),
#  ('The most relevant topic for this tweet is "sports events"', 1),
#  ('European football', 1),
#  ('Happy 1st Birthday to Ernest Brooksbank - Topic: None of the above', 1),
#  ('Euro 2024.', 1),
#  ('Family Court and Child Welfare', 1),
#  ('accidents', 1),
#  ('record-breaking animals', 1),
#  ('- European Elections', 1),
#  ('COVID-19 statistics', 1),
#  ('NFL football.', 1),
#  ('energy and renewable energy', 1),
#  ('topic: business and hospitality', 1),
#  ('Adnams CEO receiving Outstanding Contribution to Tourism award at East of England Tourism Awards - Tourism.',
#   1),
#  ('- Education', 1),
#  ('African culture and arts.', 1),
#  ('NFL/football sports', 1),
#  ('European Club Football', 1),
#  ('gender identity in education', 1),
#  ('ICC T20I Team of the Year', 1),
#  ('Recommended Topic: Tourism/Travel', 1),
#  ('topic: education opportunities', 1),
#  ('NFL & New England Patriots', 1),
#  ('Scorpions SC G08 soccer team and ECNL New England Conference', 1),
#  ('NFL and sports', 1),
#  ('Soccer / International Football', 1),
#  ('Cricket - INDvENG', 1),
#  ('10 free agent options on defense for the New England Patriots', 1),
#  ('NFL/team sports', 1),
#  ('health and longevity', 1),
#  ('agriculture & sustainability', 1),
#  ('Other topic: Easter events / Easter activities', 1),
#  ('controversial speech', 1),
#  ('Music industry', 1),
#  ('No relevant topic fits the tweet provided.', 1),
#  ('None of the given topics seem to be the best fit for the tweet provided. The recommended topic would be "Photography" for the tweet about Bruno Delannoy being a regional photographer.',
#   1),
#  ('political situation in France', 1),
#  ('podcasts', 1),
#  ("The best topic for the tweet 'Back in France' would be Emmanuel Macron.",
#   1),
#  ('None of the mentioned topics seem to align with the tweet provided. An appropriate topic could be "Social Media Updates" as the tweet appears to be referencing a social media post on Instagram.',
#   1),
#  ('I would recommend the topic of: "Hate speech and inciting violence."', 1),
#  ('None of the provided topics align perfectly with the content of the tweet. I recommend the topic: Corporate Social Responsibility.',
#   1),
#  ('I recommend the topic "Emmanuel Macron."', 1),
#  ('This tweet is most relevant to the topic of *Abortion*.', 1),
#  ('Recommended topic: Technology\n\nBest Topic: Delivery Services', 1),
#  ('Israeli-Palestinian Conflict.', 1),
#  ('WorldSkills', 1),
#  ('Other topic: Pop culture.', 1),
#  ('K-pop fandom partnership.', 1),
#  ('K-pop fandom', 1),
#  ('The best topic for the tweet "THE GOAL OF FRANCE" would be EUROPEAN ELECTIONS.',
#   1),
#  ('Olympic events', 1),
#  ('The best topic for the tweet "Majestic sentinel watching over the protection of sailors" would be Dune part two.',
#   1),
#  ('The best topic for this tweet is "aviation tracking".', 1),
#  ('topic: immigration', 1),
#  ('Other topic: Technology & Gadgets', 1),
#  ('Other Topic: Music Events', 1),
#  ('Recommended topic: Travel and Tourism', 1),
#  ('Violence and Safety', 1),
#  ('Recommending other topic: Celebrity birthdays', 1),
#  ('Charles de Gaulle Airport - travel and transportation', 1),
#  ('K-pop partnerships.', 1),
#  ('Charity and Fundraising', 1),
#  ('kpop', 1),
#  ('Topic: Video games', 1),
#  ('human rights', 1),
#  ('None of the provided topics match the content of the tweet. Another suitable topic could be religious extremism.',
#   1),
#  ('united nations', 1),
#  ('Jeffrey Epstein scandal', 1),
#  ('Job search/employment', 1),
#  ('No relevant topic found in the given options.', 1),
#  ('The best topic for the tweet \'"France"\' would be Emmanuel Macron.', 1),
#  ('school violence', 1),
#  ('Defense and military acquisitions', 1),
#  ('employment', 1),
#  ('terrorism.', 1),
#  ('The best topic for the tweet is "Canadian politics".', 1),
#  ('Entertainment', 1),
#  ('The best topic for the tweet you provided is "immigration."', 1),
#  ('The best matching topic for the tweet would be "ONEWE Dongmyeong at M Countdown".',
#   1),
#  ('Topic: European elections', 1),
#  ('olympic opening ceremony.', 1),
#  ('STEM Education', 1),
#  ('French TV Shows', 1),
#  ('K-pop social media and entertainment.', 1),
#  ('ATEEZ YEOSANG', 1),
#  ('TerresDeFrance holidays promo Indian summer', 1),
#  ('The best topic for the tweet mentioned would be "education" as the tweet mentions a university campus in Lyon, France.',
#   1),
#  ('other topic: Architecture', 1),
#  ('pokemon', 1),
#  ('The best topic for this tweet is "Olympics games."', 1),
#  ('Photography and Student Program.', 1),
#  ('European Union', 1),
#  ('Other: Aviation and Aircraft Tracking', 1),
#  ('topic: Copyright Infringement on Manga and Manhwa Reading in France', 1),
#  ('This tweet is most closely related to the topic of Emmanuel Macron.', 1),
#  ('topic: environmental issues.', 1),
#  ('(NO SPECIFIC TOPIC MATCH FOUND)', 1),
#  ('Bullying', 1),
#  ('Economic/financial matters.', 1),
#  ('The best topic for the provided tweet is "Olympic Games".', 1),
#  ('Other topic: Anime adaptations in movie theaters.', 1),
#  ('None of the provided topics match the content of the tweet.', 1),
#  ('None of the provided topics match the content of the tweet. An alternative topic that could potentially fit is "K-pop fan community partnerships."',
#   1),
#  ('Recommanded topic: Social Media Trends', 1),
#  ('Recommended topic: Environmental sustainability', 1),
#  ('European history', 1),
#  ('The best topic for the tweet "You can get eaten by people you feed Zed" is Dune part two.',
#   1),
#  ('The best topic among the options provided is "European elections."', 1),
#  ('legal issues', 1),
#  ('conflict and war', 1),
#  ('AlertesInfos Lyon and France | Immigration', 1),
#  ('labour rights', 1),
#  ('The most relevant topic for the tweet is "Immigration".', 1),
#  ('Palestine', 1),
#  ('None of the provided topics align with the content of the tweet. An appropriate topic for the tweet could be "K-pop" or "NCT Dream".',
#   1),
#  ('nuclear power', 1),
#  ('russian-ukrainian conflict', 1),
#  ('Recreation and Travel', 1)]

# %%
dataset_fin["Topics"].nunique()
# Out:
# 760

# %%
topic_1 = dataset_fin[dataset_fin["Topics"] == 'Travel and Tourism']
topic_1
# Out:
#               Username                                               Text  \
# 972            Artyrus  Je viens d'y penser mais j'ai déjà été dans 14...
# 1336    DCJeans France  💶« On a 3IIICH les premiers temps »\n❤️Marrake...
# 2019   Jonathan Levitt  Entering the 14th and final state I’ll visit/t...
# 2781       HadNews.com  Top 10 Must-Visit Destinations in the United S...
# 2883  USA TODAY Travel  Where to make a splash this summer: Best lakes...
# 2918              ITIJ  Top international destinations for US #travele...
#
#           Month  Retweets  Likes  country  \
# 972   September         0      2   France
# 1336  September         3     47   France
# 2019  September         0      2  England
# 2781       July         0      1      Usa
# 2883       June         2      1      Usa
# 2918  September         0      0      Usa
#
#                                             Text_clean1              Topics  \
# 972   I just thought about it, but I have already be...  Travel and Tourism
# 1336  We discovered Marrakech for the first time and...  Travel and Tourism
# 2019  Entering the 14th and final state Ill visittra...  Travel and Tourism
# 2781  Top 10 MustVisit Destinations in the United St...  Travel and Tourism
# 2883  Where to make a splash this summer Best lakes ...  Travel and Tourism
# 2918  Top international destinations for US traveler...  Travel and Tourism
#
#      Sentiment             Topics2
# 972   positive  european elections
# 1336  positive           Aborption
# 2019  positive  european elections
# 2781   neutral         immigration
# 2883   neutral      olympics games
# 2918   neutral         immigration

# %%
topic_1["Text_clean1"][2781]
# Out:
# 'Top 10 MustVisit Destinations in the United States in August 2024   ADVENTURE AMERICA AUGUST AUGUST_TRAVEL DESTINATIONS EXPLORATION SIGHTSEEING SUMMER SUMMER_2024 SUMMER_TRAVEL TRAVEL US_TRAVEL USA VACATION '

# %% [markdown]
# # 4. Database for Visualisation

# %%
# Connexion à SQL Server
conn = pyodbc.connect(
    "Driver={SQL Server};"
    "Server=HPMAYENE99/SQLEXPRESS;"
    "Database=PROJET_PFE;"
    "Trusted_Connection=yes;"
)
cursor = conn.cursor()

# %%
cursor.execute('''
    CREATE TABLE Tweets (
        id INT PRIMARY KEY IDENTITY(1,1),
        tweet_text NVARCHAR(MAX),
        sentiment NVARCHAR(50),
        sentiment_score FLOAT,
        timestamp DATETIME,
        country NVARCHAR(50)
    )
''')
conn.commit()
